# %%
import os

#Get list of directory content.
def get_titles():
    user_dir = "/Volumes/Drive2/Books_2/"
    if os.path.isdir(user_dir):
        dirty_titles = [os.listdir(user_dir)]
        print(dirty_titles)
        return dirty_titles
    else:
        print(f"Error: '{user_dir}' is not a valid directory.")
        return None


 #       # Create an empty list to hold our clean titles
 #       def clean_titles(dirty_titles):


            #if os.path.isdir(user_dir):
             #   dirty_titles = os.listdir(user_dir)
  #          clean_books = []

#
# clean_titles  # clean_books = [messy_filenames]
       # print(clean_books)
   # else:
       # print(f"Error: '{user_dir}' is not a valid directory.")

    # def clean_titles(messy_filenames):
    # clean_books = []
    #if os.path.isdir(user_dir):
      #  dirty_titles = os.listdir(user_dir) ###
